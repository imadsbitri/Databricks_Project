# %%
# Loading data from source to bronze layer 

df = spark.read.option("header", "true").option("inferSchema", "true").csv('/Volumes/workspace/bronze/source_systems/source_crm/cust_info.csv', header=True)     

df.display()

# %%
df.write.mode('overwrite').saveAsTable("bronze.crm_cust_info")

# %%
df = spark.read.option("header", "true").option("inferSchema", "true").csv('/Volumes/workspace/bronze/source_systems/source_crm/prd_info.csv', header=True)   
df.write.mode('overwrite').saveAsTable("bronze.crm_prd_info")

# %%
df = spark.read.option("header", "true").option("inferSchema", "true").csv('/Volumes/workspace/bronze/source_systems/source_crm/sales_details.csv', header=True)   
df.write.mode('overwrite').saveAsTable("bronze.crm_sales_details")

# %%
df = spark.read.option("header", "true").option("inferSchema", "true").csv('/Volumes/workspace/bronze/source_systems/source_erp/CUST_AZ12.csv', header=True)   
df.write.mode('overwrite').saveAsTable("bronze.erp_CUST_AZ12")

# %%
df = spark.read.option("header", "true").option("inferSchema", "true").csv('/Volumes/workspace/bronze/source_systems/source_erp/LOC_A101.csv', header=True)   
df.write.mode('overwrite').saveAsTable("bronze.erp_LOC_A101")

# %%
df = spark.read.option("header", "true").option("inferSchema", "true").csv('/Volumes/workspace/bronze/source_systems/source_erp/PX_CAT_G1V2.csv', header=True)   
df.write.mode('overwrite').saveAsTable("bronze.erp_PX_CAT_G1V2")

# %%
# %sql
select * from bronze.crm_cust_info limit 5

# %%
# %sql
select * from bronze.crm_prd_info limit 5

# %%
# %sql
select * from bronze.crm_sales_details limit 5

# %%
# %sql
select * from bronze.erp_cust_az12 limit 5

# %%
# %sql
select * from bronze.erp_loc_a101 limit 5

# %%
# %sql
select * from bronze.erp_px_cat_g1v2 limit 5
